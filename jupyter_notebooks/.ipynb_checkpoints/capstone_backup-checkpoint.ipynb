# %%
import pandas as pd
import folium
import folium.plugins as fp
from folium.plugins import HeatMap
import geopandas as gpd
from math import radians, cos, sin, asin, sqrt
from numpy import radians
import matplotlib.pyplot as plt

# %%
#### # Get Boulder, CO coords, read in response_data.csv, rename
# 'X' and 'Y' to 'long' and 'lat', and re-order to 'lat', 'long'

# boulder_coords = (40.014984, -105.270546)
# response_data = pd.read_csv('data/boulder_response_times_edit.csv')
# response_data.rename(columns={'X':'long', 'Y':'lat'}, inplace=True)
# cols = list(response_data.columns)
# a, b = cols.index('long'), cols.index('lat')
# cols[b], cols[a] = cols[a], cols[b]
# response_data = response_data[cols]
response_data = pd.read_csv('data/BFD_fire.csv')
response_data["fire_norm_time_per_dist"]= response_data['ELAPSEDENROUTE1STSCENEFIREHR'] / response_data['fire_ass_to_loc']
response_data.to_csv('data/BFD_fire.csv')
# # Drop all rows with zeros in 'lat' or 'long'.
#resp_data = response_data[(response_data[['lat','long']] != 0).all(axis=1)]

# # Create new df with just lat/long.
# incident_latlong = response_data[['lat', 'long']].copy()

# Cast the lat/long to a list
#locationlist = incident_latlong.values.tolist()
# locationlist[7] = [39.98363365628458, -105.25191229875358]
# Out:
# /home/alex/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (31,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Clean the data a little. Drop all rows with zeros in 'lat' or 'long'.
# resp_data = response_data[(response_data[['lat','long']] != 0).all(axis=1)].copy()

# To date time: RESPONSEDATE. For some reason have to do in two steps to drop empty hour:min:sec
# resp_data['RESPONSEDATE'] = pd.to_datetime(resp_data['RESPONSEDATE'])
# resp_data['RESPONSEDATE'] = pd.to_datetime(resp_data['RESPONSEDATE'],format='%m/%d/%Y').dt.date
# resp_data["month"] = resp_data['RESPONSEDATE'].map(lambda x: x.month)
# resp_data['Datetime'] = resp_data(resp_data['RESPONSEDATE'])
# resp_data.drop('Unnamed: 0', axis = 1, inplace = True)
# resp_data['Datetime'] = pd.to_datetime(resp_data['RESPONSEDATE'])
# resp_data = resp_data.set_index('Datetime')
# resp_data.sort_index(inplace = True)
# resp_data["day"] = resp_data['RESPONSEDATE'].map(lambda x: x.day)
resp_data.head()
# Out:
#                   lat        long  OBJECTID       ID MASTERINCIDENTNUMBER  \
# Datetime
# 2015-01-01  40.006661 -105.253452     15366  2293615     BFD150101-000052
# 2015-01-01  39.986564 -105.229860     15975  2293240     BFD150101-000037
# 2015-01-01  40.004591 -105.275369     15151  2293223     BFD150101-000036
# 2015-01-01  40.003217 -105.255521     15118  2293827     BFD150101-000066
# 2015-01-01  39.994322 -105.234320     14945  2293171     BFD150101-000032
#
#            RESPONSEDATE  RESPONSEHOUR  RESPONSEDOW  RESPONSEYEAR AGENCYTYPE  \
# Datetime
# 2015-01-01   2015-01-01            19            3          2015        BFD
# 2015-01-01   2015-01-01            14            3          2015        BFD
# 2015-01-01   2015-01-01            13            3          2015        BFD
# 2015-01-01   2015-01-01            23            3          2015        BFD
# 2015-01-01   2015-01-01            12            3          2015        BFD
#
#             ... ELAPSEDASSIGNED2ENROUTEFIREMIN ELAPSEDENROUTE1STSCENEFIREMIN  \
# Datetime    ...
# 2015-01-01  ...                       1.400000                      4.366667
# 2015-01-01  ...                       1.866667                      4.650000
# 2015-01-01  ...                       1.733333                      3.633333
# 2015-01-01  ...                       2.133333                      4.300000
# 2015-01-01  ...                       2.600000                      4.383333
#
#            ELAPSEDASSIGNED1STSCENEFIREMIN fire_long_ass fire_lat_ass  \
# Datetime
# 2015-01-01                       5.766667   -105.253880    40.014245
# 2015-01-01                       6.516667   -105.246994    39.980426
# 2015-01-01                       5.366667   -105.264409    40.000091
# 2015-01-01                       6.433333   -105.264409    40.000091
# 2015-01-01                       6.983333   -105.264409    40.000091
#
#            fire_ass_to_loc ELAPSEDENROUTE1STSCENEFIREHR fire_norm_mile_per_hr  \
# Datetime
# 2015-01-01        0.024438                     0.072778              0.335796
# 2015-01-01        0.907373                     0.077500             11.708037
# 2015-01-01        0.580291                     0.060556              9.582782
# 2015-01-01        0.470559                     0.071667              6.565945
# 2015-01-01        1.593118                     0.073056             21.806933
#
#             month day
# Datetime
# 2015-01-01      1   1
# 2015-01-01      1   1
# 2015-01-01      1   1
# 2015-01-01      1   1
# 2015-01-01      1   1
#
# [5 rows x 42 columns]

# %%
# haversine is a function to calculate distance between points on a sphere.
# Could also include altitude if wanted to get more accurate.
def haversine(row, lat1, lon1, lat2, lon2):

    R = 3959.87433 # this is in miles.  For Earth radius in kilometers use 6372.8 km

    lat1 = radians(row[lat1])
    lat2 = radians(row[lat2])
    dLat = radians(lat2 - lat1)
    dLon = radians(row[lon2] - row[lon1])

    a = sin(dLat/2)**2 + cos(lat1)*cos(lat2)*sin(dLon/2)**2
    c = 2*asin(sqrt(a))

    return R * c

# %%
# Create column with distance in miles between fire station and incident using haversine
resp_data["fire_ass_to_loc"] = response_data.apply(haversine, 
                                                       args=('fire_lat_ass', 'fire_long_ass',
                                                             'lat', 'long'), axis=1)

# Create column with distance in miles between amr and incident using haversine
resp_data["amr_ass_to_loc"] = response_data.apply(haversine, 
                                                       args=('amr_lat_ass', 'amr_long_ass',
                                                             'lat', 'long'), axis=1)
# Check to make sure haversince worked correctly
# response_data['fire_ass_to_loc'].head()

# %%
# Create columns with time enroute in hours
resp_data['ELAPSEDENROUTE1STSCENEFIREHR'] = resp_data['ELAPSEDENROUTE1STSCENEFIREMIN']/60
resp_data['ELAPSEDENROUTE1STSCENEAMRHR'] = resp_data['ELAPSEDENROUTE1STSCENEAMRMIN']/60

# Normalize distance over time to find "routes" that take longer. Can use to look at time of day, etc...
resp_data["fire_norm_mile_per_hr"]= resp_data['fire_ass_to_loc'] / resp_data['ELAPSEDENROUTE1STSCENEFIREHR']
resp_data["amr_norm_mile_per_hr"]= resp_data['amr_ass_to_loc'] / resp_data['ELAPSEDENROUTE1STSCENEAMRHR']

# %%
# create empty map zoomed in on Boulder, CO
map = folium.Map(location=boulder_coords, zoom_start=12)

# Test with SMALL subset of data
for point in range(0, 50):
    folium.Marker(locationlist[point], popup = response_data['INCIDENTTYPE'][point]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Attempt to clean up the map. Instantiate a new map first.
map2 = folium.Map(location=boulder_coords, zoom_start=12)

marker_cluster = fp.MarkerCluster().add_to(map2)

# Remember to try a small subset of data.
for point in range(0, 50):
    folium.Marker(locationlist[point], popup = response_data['INCIDENTTYPE'][point]).add_to(marker_cluster)
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Attempt 3: Larger subset of data. Testing icons.

map3 = folium.Map(location=boulder_coords, tiles='CartoDB positron', zoom_start=11)

marker_cluster = fp.MarkerCluster().add_to(map3)

# Try a larger subset of data with less zoom:
for point in range(0, 500):
    folium.Marker(locationlist[point], popup = response_data['INCIDENTTYPE'][point], icon = folium.Icon(icon = 'fire')).add_to(marker_cluster)

map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Prepping for map 4:

def program_area_icons(df):
    if df['PROGRAMAREA'] == 'Fire':
        return 'fire'
    elif df['PROGRAMAREA'] == 'Rescue':
        return 'flag'
    elif df['PROGRAMAREA'] == 'EMS':
        return 'plus-sign'
    elif df['PROGRAMAREA'] == 'Hazmat':
        return 'warning-sign'
    elif df['PROGRAMAREA'] == 'Mutual Aid':
        return 'user'
    else:
        return 'asterisk'
response_data["response_icon"] = response_data.apply(program_area_icons, axis=1)

def incident_year(df):
    if df['RESPONSEYEAR'] == 2015:
        return 'red'
    elif df['RESPONSEYEAR'] == 2016:
        return 'orange'
    elif df['RESPONSEYEAR'] == 2017:
        return 'green'
    elif df['RESPONSEYEAR'] == 2018:
        return 'darkblue'
    elif df['RESPONSEYEAR'] == 2019:
        return 'darkpurple'
    else:
        return 'gray'
response_data["year_color"] = response_data.apply(incident_year, axis=1)

# %%
map4 = folium.Map(location=boulder_coords, tiles='CartoDB positron', zoom_start=11)

marker_cluster = fp.MarkerCluster().add_to(map4)

# Try adding markers specific to year and responseprogram:
for point in range(0, 500):
    folium.Marker(locationlist[point], popup = response_data['INCIDENTTYPE'][point], 
    icon = folium.Icon(icon = response_data['response_icon'][point], 
    color = response_data['year_color'][point])).add_to(marker_cluster)

map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map5 = folium.Map(location=boulder_coords, tiles='CartoDB positron', zoom_start=11)

# marker_cluster = fp.MarkerCluster().add_to(map5)

#Try adding markers specific to year and responseprogram:
# for point in range(0, 500):
#     HeatMap(locationlist[point].add_to(map5)


# # List comprehension to make out list of lists
# heat_data = [locationlist[point] 
#              for index, row in heat_df.iterrows()]
locationlist_short = locationlist[0:20000]
HeatMap(locationlist_short, min_opacity=0.2,
                   max_val=float(60),
                   radius=5.5, blur=5, 
                   max_zoom=1, ).add_to(map5)
map5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## List of potential icons:
#  fire
#  warning-sign (light with dark), alert (dark with light)
#  thumbs-up
#  questions-sign
#  tint (looks like a water drop)
#  flag
#  home
#  ok (check mark)
#  plus (could be for medic?)
#  leaf
#  flash (lightning bolt)
#  earphone (telephone receiver)
#  phone-alt (whole telephone)
#  cutlery
#  tree-conifer, tree-deciduous
#  bed
#  hourglass
#  education (graduation cap)
#  oil (oil barrel)
#  exclamation-sign
#  asterisk

# %% [markdown]
# ## Types of responses:
#  Mutual Aid
#  Rescue
#  EMS
#  Fire
#  Hazmat

# %%
# Split response_data into separate years
boulder_2015 = response_data[response_data['RESPONSEYEAR'] == 2015]
incident_latlong_15 = boulder_2015[['lat', 'long']].copy()
locationlist_15 = incident_latlong.values.tolist()

boulder_2016 = response_data[response_data['RESPONSEYEAR'] == 2016]
incident_latlong_16 = boulder_2016[['lat', 'long']].copy()
locationlist_16 = incident_latlong.values.tolist()

boulder_2017 = response_data[response_data['RESPONSEYEAR'] == 2017]
incident_latlong_17 = boulder_2017[['lat', 'long']].copy()
locationlist_17 = incident_latlong.values.tolist()

boulder_2018 = response_data[response_data['RESPONSEYEAR'] == 2018]
incident_latlong_18 = boulder_2018[['lat', 'long']].copy()
locationlist_18 = incident_latlong.values.tolist()

boulder_2019 = response_data[response_data['RESPONSEYEAR'] == 2019]
incident_latlong_19 = boulder_2019[['lat', 'long']].copy()
locationlist_19 = incident_latlong.values.tolist()

# %%
resp_data.head()
# Out:
#          lat        long  OBJECTID       ID MASTERINCIDENTNUMBER RESPONSEDATE  \
# 0  40.032871 -105.287416      2001  3240840     BFD160712-007613   2016-07-12
# 1  40.021740 -105.258863      2002  3240964     BFD160712-007614   2016-07-12
# 2  40.029174 -105.263131      2003  3235971     BFD160709-007519   2016-07-09
# 3  39.997265 -105.250782      2004  2646739     BFD150727-007515   2015-07-27
# 4  40.019934 -105.271681      2005  2647244     BFD150727-007527   2015-07-27
#
#    RESPONSEHOUR  RESPONSEDOW  RESPONSEYEAR AGENCYTYPE  ... fire_long_ass  \
# 0            11            1          2016        BFD  ...      0.000000
# 1            12            1          2016        BFD  ...   -105.253880
# 2            20            5          2016        BFD  ...   -105.280272
# 3             1            0          2015        BFD  ...   -105.264071
# 4            11            0          2015        BFD  ...   -105.280272
#
#   fire_lat_ass amr_long_ass amr_lat_ass fire_ass_to_loc amr_ass_to_loc  \
# 0     0.000000  -105.262692   39.998875     6091.947863       1.309287
# 1    40.014245  -105.256054   40.013840        0.263882       0.148964
# 2    40.022858  -105.259753   40.033999        0.907205       0.178841
# 3    40.000530  -105.235477   40.014809        0.703602       0.810492
# 4    40.022858  -105.276062   40.018705        0.454686       0.231862
#
#   ELAPSEDENROUTE1STSCENEFIREHR ELAPSEDENROUTE1STSCENEAMRHR  \
# 0                          NaN                    0.187778
# 1                     0.073889                    0.085833
# 2                     0.064722                    0.018611
# 3                     0.050556                    0.056389
# 4                     0.048333                    0.018333
#
#   fire_norm_mile_per_hr amr_norm_mile_per_hr
# 0                   NaN             6.972537
# 1              3.571341             1.735505
# 2             14.016896             9.609390
# 3             13.917401            14.373256
# 4              9.407297            12.647007
#
# [5 rows x 75 columns]

# %% [markdown]
# ## Columns to consider:
# - ELAPSEDASSIGNED2ENROUTEFIREMIN (minutes converted to decimals)
# - ELAPSEDASSIGNED2ENROUTEAMRMIN (minutes converted to decimals)
# - ELAPSEDENROUTE1STSCENEFIREMIN (minutes converted to decimals)
# - ELAPSEDENROUTE1STSCENEAMRMIN (minutes converted to decimals)
# - ELAPSEDASSIGNED1STSCENEFIREMIN (minutes converted to decimals)
# - ELAPSEDASSIGNED1STSCENEAMRMIN (minutes converted to decimals)
# --- ELAPSEDASSIGNED2ENROUTE + ELAPSEDENROUTE1STSCENE (should) = ELAPSEDASSIGNED1STSCENE
# --- Those first 6 columns all exist w/o the -MIN at the end, with time in normal date-time format (w/o date)
# - TIMEFIRSTFIREENROUTE (year-month-day hh:mm:ss)
# - TIMEFIRSTAMRENROUTE (year-month-day hh:mm:ss)
# - TIMEFIRSTFIREARRIVED (year-month-day hh:mm:ss)
# - TIMEFIRSTAMRARRIVED (year-month-day hh:mm:ss)
# - TIMEFIRSTFIREASSIGNED (year-month-day hh:mm:ss)
# - TIMEFIRSTAMRASSIGNED (year-month-day hh:mm:ss)
# - VEHICLENUMBERFIRE
# - VEHICLENUMBERAMR
# - SEVERITY (A,B,C,D,E) - lots of blanks
# - PROBLEM (many elements start with 'z', so will have to drop those)
# - INCIDENTTYPE (would have to get some clarification on what all the codes mean)
# - RESPONSEHOUR (0-23)
# - RESPONSEDOW (Day Of Week: 0-6)
# - RESPONSEDATE (already formatted into datetime and dropped hours)

# %% [markdown]
# ## GROUPBY's?
# - date, hour, vehicle number to get a sense of how many times same unit is going out in a day?

# %% [markdown]
# ## Questions:
# - Does severity affect response time?
# - Does hour the call comes in affect response time? Day of week?
# - Can I make an association between date, hour, vehicle number to get an idea of the same crew going out multiple times in a day?

# %%
# Created data set
# resp_data.to_csv('data/resp_data.csv')

# %%
gb_year = resp_data.groupby('RESPONSEYEAR')

# %%
c = gb_year['ID'].count().reset_index()
c
# Out:
#    RESPONSEYEAR     ID
# 0          2015  12156
# 1          2016  13143
# 2          2017  13224
# 3          2018  12940
# 4          2019   9122

# %%
inc_per_year = plt.bar(x = c['RESPONSEYEAR'], height = c['ID'])

# %%
# len(resp_data['long'].unique())

# %%
resp_data_rnd = resp_data.round(6)

# %%
# resp_data_rnd.head()

# %%
# len(resp_data['lat'].unique())

# %%
# test = resp_data.groupby(['lat', 'long'])

# %%
# test.count().sort_values('ID', ascending = False)

# %%
most_com = resp_data[resp_data['lat'] == 40.005051353787]

# %%
most_com_2 = resp_data_rnd[resp_data_rnd['lat'] == 40.005051]

# %%
print(resp_data_rnd.iloc[42,0])
print(resp_data.iloc[42,0])
# Out:
# 40.005051
# 40.005051353786996

# %%
most_com_2.sort_values('RESPONSEDATE')
# Out:
#              lat        long  OBJECTID       ID MASTERINCIDENTNUMBER  \
# 15441  40.005051 -105.256579     15442  2292670     BFD150101-000005
# 16511  40.005051 -105.256579     16512  2293971     BFD150102-000073
# 2763   40.005051 -105.256579      3764  2294709     BFD150102-000090
# 2780   40.005051 -105.256579      3781  2295283     BFD150102-000106
# 5843   40.005051 -105.256579      4844  2296158     BFD150103-000129
# 5838   40.005051 -105.256579      4839  2295902     BFD150103-000121
# 5801   40.005051 -105.256579      4802  2297116     BFD150104-000160
# 5545   40.005051 -105.256579      4546  2297074     BFD150104-000159
# 5155   40.005051 -105.256579      4156  2297454     BFD150104-000169
# 5430   40.005051 -105.256579      4431  2300239     BFD150106-000246
# 15286  40.005051 -105.256579     15287  2308592     BFD150112-000436
# 57369  40.005051 -105.256579    166747  5071302     BFD190612-006312
# 57379  40.005051 -105.256579    167061  5071925     BFD190613-006322
#
#       RESPONSEDATE  RESPONSEHOUR  RESPONSEDOW  RESPONSEYEAR AGENCYTYPE  ...  \
# 15441   2015-01-01             0            3          2015        BFD  ...
# 16511   2015-01-02             3            4          2015        BFD  ...
# 2763    2015-01-02            14            4          2015        BFD  ...
# 2780    2015-01-02            21            4          2015        BFD  ...
# 5843    2015-01-03            15            5          2015        BFD  ...
# 5838    2015-01-03            11            5          2015        BFD  ...
# 5801    2015-01-04            14            6          2015        BFD  ...
# 5545    2015-01-04            13            6          2015        BFD  ...
# 5155    2015-01-04            19            6          2015        BFD  ...
# 5430    2015-01-06            13            1          2015        BFD  ...
# 15286   2015-01-12             8            0          2015        BFD  ...
# 14180   2015-01-12            22            0          2015        BFD  ...
# 13711   2015-01-14            12            2          2015        BFD  ...
# 15072   2015-01-14             8            2          2015        BFD  ...
# 13884   2015-01-17             8            5          2015        BFD  ...
# 2189    2015-01-23            13            4          2015        BFD  ...
# 2185    2015-01-25            21            6          2015        BFD  ...
# 907     2015-01-25            16            6          2015        BFD  ...
# 44548   2015-01-26             9            0          2015        BFD  ...
# 620     2015-01-27            16            1          2015        BFD  ...
# 45134   2015-02-05            21            3          2015        BFD  ...
# 27411   2015-02-05            20            3          2015        BFD  ...
# 28085   2015-02-06            17            4          2015        BFD  ...
# 27413   2015-02-08            12            6          2015        BFD  ...
# 28283   2015-02-08            14            6          2015        BFD  ...
# 28141   2015-02-10            13            1          2015        BFD  ...
# 28128   2015-02-10             5            1          2015        BFD  ...
# 25733   2015-02-15            12            6          2015        BFD  ...
# 27959   2015-02-15            19            6          2015        BFD  ...
# 25610   2015-02-19             4            3          2015        BFD  ...
# ...            ...           ...          ...           ...        ...  ...
# 56080   2019-05-06            14            0          2019        BFD  ...
# 56125   2019-05-08             1            2          2019        BFD  ...
# 56175   2019-05-09             8            3          2019        BFD  ...
# 56258   2019-05-11            12            5          2019        BFD  ...
# 56360   2019-05-14            15            1          2019        BFD  ...
# 56456   2019-05-17            13            4          2019        BFD  ...
# 56497   2019-05-18            15            5          2019        BFD  ...
# 56578   2019-05-21            10            1          2019        BFD  ...
# 56629   2019-05-23             5            3          2019        BFD  ...
# 56639   2019-05-23            14            3          2019        BFD  ...
# 56657   2019-05-24             4            4          2019        BFD  ...
# 56685   2019-05-24            17            4          2019        BFD  ...
# 56717   2019-05-25            14            5          2019        BFD  ...
# 56729   2019-05-25            20            5          2019        BFD  ...
# 56732   2019-05-25            21            5          2019        BFD  ...
# 56738   2019-05-26             3            6          2019        BFD  ...
# 56743   2019-05-26             7            6          2019        BFD  ...
# 56758   2019-05-26            20            6          2019        BFD  ...
# 56765   2019-05-27             1            0          2019        BFD  ...
# 56835   2019-05-29            10            2          2019        BFD  ...
# 56902   2019-05-31             7            4          2019        BFD  ...
# 56909   2019-05-31             9            4          2019        BFD  ...
# 56999   2019-06-02            12            6          2019        BFD  ...
# 57007   2019-06-02            19            6          2019        BFD  ...
# 56657       0.205738                     0.040556                    0.072500
# 56685    6091.934956                     0.130556                         NaN
# 56717       0.146458                     0.013611                    0.022500
# 56729       1.131770                          NaN                    0.079444
# 56732       0.031517                     0.044722                    0.074444
# 56738    6091.934956                     0.057778                         NaN
# 56743       8.961775                     0.046667                    0.065000
# 56758       1.139710                     0.038333                    0.062500
# 56765    6091.934956                     0.040833                         NaN
# 56835       0.166721                          NaN                    0.028889
# 56902       0.020042                     0.070833                    0.000833
# 56909       8.992981                     0.050556                    0.063056
# 56999    6091.934956                     0.039444                         NaN
# 57007       1.148708                     0.036667                    0.054722
# 57051       0.866034                          NaN                    0.072778
# 57147       1.127006                     0.030833                    0.043889
# 57149       0.343180                          NaN                    0.044444
# 57294       0.124280                     0.058611                    0.069167
# 57369       0.027856                     0.033333                    0.052778
# 57379       1.113771                     0.038333                    0.021944
#
#       fire_norm_mile_per_hr amr_norm_mile_per_hr
# 15441                   NaN            11.017885
# 16511              5.876187             4.068497
# 2763               9.629366             6.544974
# 2780               9.270508            11.065860
# 5843               2.046882             4.086906
# 5838              10.510926             8.011674
# 5801               2.788186            11.514476
# 5545               9.328447             2.625606
# 5155                    NaN             6.210131
# 5430                    NaN             6.643830
# 15286                   NaN             4.855392
# 14180              2.729176            10.487030
# 13711                   NaN             1.500980
# 15072              8.200833             5.266509
# 13884                   NaN             6.338290
# 2189                    NaN             4.691981
# 2185               4.262928             1.270829
# 907               17.623546                  NaN
# 44548             22.486069            35.750216
# 620                     NaN             3.528150
# 45134              2.456259                  NaN
# 27411              6.279168             3.794364
# 28085                   NaN             8.556442
# 27413                   NaN             7.897585
# 28283              1.029570             1.936134
# 28141              2.672613            11.174704
# 28128                   NaN             4.240405
# 25733                   NaN            13.578824
# 27959              3.485232             6.521345
# 25610              3.285442                  NaN
# ...                     ...                  ...
# 56080              8.826712             0.402854
# 56125                   NaN            25.273413
# 56175              4.845753             0.330609
# 56258              6.005686            20.823626
# 56360                   NaN             0.388570
# 56456                   NaN            33.036150
# 56497              1.969938            19.943054
# 56578              6.288024             9.765592
# 56629              3.054429            27.784918
# 56639              3.039176            21.993502
# 56657              3.100666             2.837762
# 56685              1.156223                  NaN
# 56717             11.629688             6.509250
# 56729                   NaN            14.246053
# 56732              3.012047             0.423358
# 56738              2.342388                  NaN
# 56743              8.801393           137.873467
# 56758              3.552509            18.235353
# 56765              3.221510                  NaN
# 56835                   NaN             5.771112
# 56902              1.847403            24.050991
# 56909              2.727349           142.619961
# 56999              3.495138                  NaN
# 57007              3.461285            20.991610
# 57051                   NaN            11.899707
# 57147              4.451299            25.678619
# 57149                   NaN             7.721551
# 57294              5.994173             1.796819
# 57369              4.068058             0.527792
# 57379              3.376728            50.754115
#
# [1287 rows x 75 columns]

# %%
# test.count().sort_values('ID', ascending = False)
# most_com_group = most_com_2.groupby('RESPONSEHOUR')

# %%
# most_com_group.count()
# most_com_group.sort_values('RESPONSEHOUR', ascending = True)

# %%
# resp_data['ELAPSEDASSIGNED2ENROUTEFIREMIN'].mean()

# %%
# x = resp_data.groupby('RESPONSEHOUR').count()
# x

# %%
# x['ELAPSEDASSIGNED2ENROUTEFIREMIN']

# %%
# test = resp_data.set_index('RESPONSEDATE')
# df.set_index('Date', inplace=True)
# resp_data.groupby(pd.Grouper(freq='M'))
# df.groupby(Grouper(key='A'))
# b.groupby(by=[b.index.month, b.index.year])
# resp_data.info()
# resp_data.groupby(by=[resp_data.index.month])
# type(resp_data.index)

# %%
# resp_data['RESPONSEDATE'] == type(pd.datetime.date)
# b.groupby(by=[b.index.month, b.index.year])
# type(resp_data['RESPONSEDATE'][55])

# %%
#testy = resp_data(resp_data.loc[:,'RESPONSEDATE'].month)
# response_data['RESPONSEDATE'].max()

# %%
resp_data['Datetime'] = pd.to_datetime(resp_data['RESPONSEDATE'])
resp_data = resp_data.set_index('Datetime')
resp_data.head()
# Out:
#          lat        long  OBJECTID       ID MASTERINCIDENTNUMBER RESPONSEDATE  \
# 0  40.032871 -105.287416      2001  3240840     BFD160712-007613   2016-07-12
# 1  40.021740 -105.258863      2002  3240964     BFD160712-007614   2016-07-12
# 2  40.029174 -105.263131      2003  3235971     BFD160709-007519   2016-07-09
# 3  39.997265 -105.250782      2004  2646739     BFD150727-007515   2015-07-27
# 4  40.019934 -105.271681      2005  2647244     BFD150727-007527   2015-07-27
#
#    RESPONSEHOUR  RESPONSEDOW  RESPONSEYEAR AGENCYTYPE  ... fire_long_ass  \
# 0            11            1          2016        BFD  ...      0.000000
# 1            12            1          2016        BFD  ...   -105.253880
# 2            20            5          2016        BFD  ...   -105.280272
# 3             1            0          2015        BFD  ...   -105.264071
# 4            11            0          2015        BFD  ...   -105.280272
#
#   fire_lat_ass amr_long_ass amr_lat_ass fire_ass_to_loc amr_ass_to_loc  \
# 0     0.000000  -105.262692   39.998875     6091.947863       1.309287
# 1    40.014245  -105.256054   40.013840        0.263882       0.148964
# 2    40.022858  -105.259753   40.033999        0.907205       0.178841
# 3    40.000530  -105.235477   40.014809        0.703602       0.810492
# 4    40.022858  -105.276062   40.018705        0.454686       0.231862
#
#   ELAPSEDENROUTE1STSCENEFIREHR ELAPSEDENROUTE1STSCENEAMRHR  \
# 0                          NaN                    0.187778
# 1                     0.073889                    0.085833
# 2                     0.064722                    0.018611
# 3                     0.050556                    0.056389
# 4                     0.048333                    0.018333
#
#   fire_norm_mile_per_hr amr_norm_mile_per_hr
# 0                   NaN             6.972537
# 1              3.571341             1.735505
# 2             14.016896             9.609390
# 3             13.917401            14.373256
# 4              9.407297            12.647007
#
# [5 rows x 75 columns]

# %%
# resp_data['Datetime'].head()
type(resp_data.index)
resp_data_month = resp_data.groupby(by=[resp_data.index.month])

# %%
# resp_data_month
# resp_data_month.count().sort_values('ID')
# test.count().sort_values('ID', ascending = False)

# %%
resp_data.to_csv('data/BFD_fire.csv')

# %%
sns.choose_cubehelix_palette(as_cmap=True)
# Out:
# interactive(children=(IntSlider(value=9, description='n_colors', max=16, min=2), FloatSlider(value=0.0, descri…

# %%
import seaborn as sns
